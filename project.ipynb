# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import pmdarima as pm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from plotly.offline import iplot 
from dmba import regressionSummary
import csv
from datetime import datetime
from datetime import date
from statsmodels.tsa import tsatools
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns

# %% [markdown]
# #  Research Question 1:

# %% [markdown]
# Which features have the most important weight on the housing prices (Regression model）

# %%
df=pd.read_csv('redfinOutput.csv')
df
# Out:
#      Unnamed: 0                              Address        Sold  \
# 0             1     62 Shaniko Cmn,Fremont, CA 94539    $800,000
# 1             2  45552 Cheyenne Pl,Fremont, CA 94539  $1,880,000
# 2             3    1201 Valdez Way,FREMONT, CA 94539  $1,800,000
# 3             4    39762 Blacow Rd,Fremont, CA 94538  $1,150,000
# 4             5   4405 Calypso Ter,Fremont, CA 94555  $1,530,000
# ..          ...                                  ...         ...
# 345         346  WARM SPRINGS BLVD,FREMONT, CA 94538    $910,384
# 346         347          MOWRY AVE,FREMONT, CA 94538  $1,498,537
# 347         348          MOWRY AVE,FREMONT, CA 94538  $1,510,364
# 348         349  WARM SPRINGS BLVD,FREMONT, CA 94538  $2,401,874
# 349         350  WARM SPRINGS BLVD,FREMONT, CA 94538  $2,538,257
#
#         Sold Date  Bed  Bath   Size       Lot Size   HOA Year Build  \
# 0     OCT 1, 2021    3   2.0  1,150              0  $310       1987
# 1     OCT 1, 2021    4   2.0  1,531  6,300 Sq. Ft.     0       1969
# 2     OCT 1, 2021    3   2.0  1,956  6,600 Sq. Ft.     0       1971
# 3     OCT 1, 2021    3   2.0  1,585  6,400 Sq. Ft.     0       1961
# 4     OCT 1, 2021    4   2.5  1,811  5,202 Sq. Ft.   $50       1992
# ..            ...  ...   ...    ...            ...   ...        ...
# 345  AUG 20, 2021    2   2.0  1,265              0     0       2020
# 346   AUG 2, 2021    0   0.0      0  4,519 Sq. Ft.     0          —
# 347  JUL 30, 2021    0   0.0      0  5,210 Sq. Ft.     0          —
# 348  AUG 13, 2021    0   0.0      0              0     0          —
# 349  AUG 13, 2021    0   0.0      0              0     0          —
#
#                           Type
# 0                  Condo/Co-op
# 1    Single Family Residential
# 2    Single Family Residential
# 3    Single Family Residential
# 4    Single Family Residential
# ..                         ...
# 345                Condo/Co-op
# 346  Single Family Residential
# 347  Single Family Residential
# 348  Single Family Residential
# 349  Single Family Residential
#
# [350 rows x 11 columns]

# %%
d=df['Sold'].str.lstrip('$')
sold=[]
for string in d:
    newstring = ''.join([i for i in string if i.isdigit()])
    sold.append(int(newstring))
df['sold']=pd.DataFrame(sold)

# %%
df = df.drop(df[df.Bed == 0].index)

# %%
df = df.drop(df[df.Bath == 0].index)

# %%
year_build=[]
for x in df['Year Build']:
    if len(x)<4:
        year_build.append(0)
    else:
        year_build.append(x)

# %%
df['year_build']=pd.DataFrame(year_build)

# %%
df = df.drop(df[df.year_build == 0].index)
df
# Out:
#      Unnamed: 0                                          Address        Sold  \
# 0             1                 62 Shaniko Cmn,Fremont, CA 94539    $800,000
# 1             2              45552 Cheyenne Pl,Fremont, CA 94539  $1,880,000
# 2             3                1201 Valdez Way,FREMONT, CA 94539  $1,800,000
# 3             4                39762 Blacow Rd,Fremont, CA 94538  $1,150,000
# 4             5               4405 Calypso Ter,Fremont, CA 94555  $1,530,000
# ..          ...                                              ...         ...
# 341         342               48535 Spokane Rd,Fremont, CA 94539  $1,910,336
# 342         343  103 Boston Fern Cmn Unit U247,Fremont, CA 94539    $975,465
# 343         344                2881 Predio Ter,Fremont, CA 94539  $1,367,620
# 344         345              WARM SPRINGS BLVD,FREMONT, CA 94538  $1,063,074
# 345         346              WARM SPRINGS BLVD,FREMONT, CA 94538    $910,384
#
#         Sold Date  Bed  Bath   Size       Lot Size   HOA Year Build  \
# 0     OCT 1, 2021    3   2.0  1,150              0  $310       1987
# 1     OCT 1, 2021    4   2.0  1,531  6,300 Sq. Ft.     0       1969
# 2     OCT 1, 2021    3   2.0  1,956  6,600 Sq. Ft.     0       1971
# 3     OCT 1, 2021    3   2.0  1,585  6,400 Sq. Ft.     0       1961
# 4     OCT 1, 2021    4   2.5  1,811  5,202 Sq. Ft.   $50       1992
# ..            ...  ...   ...    ...            ...   ...        ...
# 341  JUL 19, 2021    4   2.0  2,122              0     0       1977
# 342  AUG 12, 2021    2   2.0  1,382              0     0       2008
# 343  JUL 19, 2021    4   4.0  2,108              0     0       2015
# 344  AUG 24, 2021    2   2.0  1,265              0     0       2019
# 345  AUG 20, 2021    2   2.0  1,265              0     0       2020
#
#                           Type     sold year_build
# 0                  Condo/Co-op   800000       1987
# 1    Single Family Residential  1880000       1969
# 2    Single Family Residential  1800000       1971
# 3    Single Family Residential  1150000       1961
# 4    Single Family Residential  1530000       1992
# ..                         ...      ...        ...
# 341  Single Family Residential  1910336       2008
# 342                Condo/Co-op   975465       2015
# 343                Condo/Co-op  1367620       2019
# 344                Condo/Co-op  1063074       2020
# 345                Condo/Co-op   910384        NaN
#
# [325 rows x 13 columns]

# %%
df=df.dropna()

# %%
df['year_build']=df['year_build'].astype(int)
# Out:
# <ipython-input-1099-0390e994e55d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_build']=df['year_build'].astype(int)

# %%
s=2021-df['year_build']

# %%
s
# Out:
# 0      34
# 1      52
# 2      50
# 3      60
# 4      29
#        ..
# 340    44
# 341    13
# 342     6
# 343     2
# 344     1
# Name: year_build, Length: 324, dtype: int32

# %%
df['year_since_built']=pd.DataFrame(s)
# Out:
# <ipython-input-1102-be1cf70dc0ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_since_built']=pd.DataFrame(s)

# %%
size=[]
for string in df['Size']:
    newstring = ''.join([i for i in string if i.isdigit()])
    size.append(int(newstring))

# %%
df['size']=pd.DataFrame(size)
df
# Out:
# <ipython-input-1104-7ac6cc289197>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['size']=pd.DataFrame(size)
#      Unnamed: 0                                          Address        Sold  \
# 0             1                 62 Shaniko Cmn,Fremont, CA 94539    $800,000
# 1             2              45552 Cheyenne Pl,Fremont, CA 94539  $1,880,000
# 2             3                1201 Valdez Way,FREMONT, CA 94539  $1,800,000
# 3             4                39762 Blacow Rd,Fremont, CA 94538  $1,150,000
# 4             5               4405 Calypso Ter,Fremont, CA 94555  $1,530,000
# ..          ...                                              ...         ...
# 340         341            4991 Conway Ter #53,Fremont, CA 94555  $1,144,571
# 341         342               48535 Spokane Rd,Fremont, CA 94539  $1,910,336
# 342         343  103 Boston Fern Cmn Unit U247,Fremont, CA 94539    $975,465
# 343         344                2881 Predio Ter,Fremont, CA 94539  $1,367,620
# 344         345              WARM SPRINGS BLVD,FREMONT, CA 94538  $1,063,074
#
#         Sold Date  Bed  Bath   Size       Lot Size   HOA Year Build  \
# 0     OCT 1, 2021    3   2.0  1,150              0  $310       1987
# 1     OCT 1, 2021    4   2.0  1,531  6,300 Sq. Ft.     0       1969
# 2     OCT 1, 2021    3   2.0  1,956  6,600 Sq. Ft.     0       1971
# 3     OCT 1, 2021    3   2.0  1,585  6,400 Sq. Ft.     0       1961
# 4     OCT 1, 2021    4   2.5  1,811  5,202 Sq. Ft.   $50       1992
# ..            ...  ...   ...    ...            ...   ...        ...
# 340   SEP 7, 2021    3   3.0  1,309              0     0       1988
# 341  JUL 19, 2021    4   2.0  2,122              0     0       1977
# 342  AUG 12, 2021    2   2.0  1,382              0     0       2008
# 343  JUL 19, 2021    4   4.0  2,108              0     0       2015
# 344  AUG 24, 2021    2   2.0  1,265              0     0       2019
#
#                           Type     sold  year_build  year_since_built    size
# 0                  Condo/Co-op   800000        1987                34  1150.0
# 1    Single Family Residential  1880000        1969                52  1531.0
# 2    Single Family Residential  1800000        1971                50  1956.0
# 3    Single Family Residential  1150000        1961                60  1585.0
# 4    Single Family Residential  1530000        1992                29  1811.0
# ..                         ...      ...         ...               ...     ...
# 340                Condo/Co-op  1144571        1977                44     NaN
# 341  Single Family Residential  1910336        2008                13     NaN
# 342                Condo/Co-op   975465        2015                 6     NaN
# 343                Condo/Co-op  1367620        2019                 2     NaN
# 344                Condo/Co-op  1063074        2020                 1     NaN
#
# [324 rows x 15 columns]

# %%
df=df.dropna()

# %%
df=df[['Bed','Bath','size','year_since_built','sold']]

# %%
df['sold']=df['sold']/1000000

# %%
df
# Out:
#      Bed  Bath    size  year_since_built   sold
# 0      3   2.0  1150.0                34  0.800
# 1      4   2.0  1531.0                52  1.880
# 2      3   2.0  1956.0                50  1.800
# 3      3   2.0  1585.0                60  1.150
# 4      4   2.5  1811.0                29  1.530
# ..   ...   ...     ...               ...    ...
# 319    3   3.0  1309.0                61  1.525
# 320    4   3.5  2122.0                 5  1.800
# 321    3   3.0  1382.0                 4  0.935
# 322    3   2.0  2108.0                63  1.220
# 323    3   3.5  1265.0                 5  1.100
#
# [304 rows x 5 columns]

# %%
x=df.iloc[:,:-1]
print(x.describe())
y=df['sold']
x_train,x_test,y_train,y_test=train_test_split(x,y)

transfer=StandardScaler()
x_train=transfer.fit_transform(x_train)
x_test=transfer.fit_transform(x_test)

estimator=LinearRegression()
estimator.fit(x_train,y_train)
print(estimator.coef_)
y_predict=estimator.predict(x_test)
score=estimator.score(x_test,y_test)
print(score)
estimator.intercept_
# Out:
#               Bed        Bath         size  year_since_built
# count  304.000000  304.000000   304.000000        304.000000
# mean     3.197368    2.296053  1631.529605         41.480263
# std      0.912252    0.749819   695.720814         18.396430
# min      1.000000    1.000000   593.000000          1.000000
# 25%      3.000000    2.000000  1228.000000         32.000000
# 50%      3.000000    2.000000  1503.000000         43.000000
# 75%      4.000000    2.500000  1819.500000         58.000000
# max      6.000000    5.500000  6787.000000         80.000000
# [0.26526805 0.24431468 0.04862064 0.07432199]
# 0.6856747373337135
# 1.3716029429824566

# %%
score=[0.253,0.266,0.063,0.066]
import matplotlib.pyplot as plt
plt.bar(x=['bed','bath','size','year_since_built'],height=score)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Analysis:

# %% [markdown]
# The size is not the dominant factor for housing price.

# %% [markdown]
# # Research Question 2:

# %% [markdown]
# Which type of houses was the most  popular  in Fremont in the past three years?

# %%
file=pd.read_csv('Fremont 3 years.csv',parse_dates=True)
file['Type'].value_counts()
# Out:
# Single Family Residential    225
# Condo/Co-op                   84
# Townhouse                     40
# Multi-Family (2-4 Unit)        1
# Name: Type, dtype: int64

# %%
lables='Single Family Residential','Condon/Co-op','Townhouse','Multi-Family(2-4 Unit)'
colors=['yellowgreen', 'gold', 'lightskyblue','red']
sizes = [225, 84, 40, 1]
explode = (0.1, 0, 0, 0)
fig1, ax1 = plt.subplots() 
ax1.pie(sizes, explode=explode, labels=lables,colors=colors,autopct='%.1f%%',pctdistance = 0.8,
        shadow=True, startangle=0,frame = False)
ax1.axis('equal')
plt.show()

# %% [markdown]
# # Analysis:
#
# The single family house was the most popular type of homes in Fremont,CA in the past 3 years.

# %% [markdown]
# Using time series -autoARIMA  module to predict the number of houses that will be sold in the next 3 months.

# %%
# Convert the date information to a datetime object as monthly data.
file['Sold Date'].value_counts()
file['Sold Date']=pd.to_datetime(file['Sold Date'])

file['year_of_sold'] = file['Sold Date'].map(lambda x: x.strftime('%Y'))
file['YM_of_sold'] = file['Sold Date'].map(lambda x: x.strftime('%Y-%m'))
df_new=file.groupby('YM_of_sold').size().to_frame(name = 'counts')
df_new
# Out:
#             counts
# YM_of_sold
# 2018-10         17
# 2018-11          7
# 2018-12         10
# 2019-01          9
# 2019-02          9
# 2019-03         13
# 2019-04         13
# 2019-05         18
# 2019-06         21
# 2019-07         16
# 2019-08         14
# 2019-09         14
# 2019-10         11
# 2019-11          6
# 2019-12          8
# 2020-01          6
# 2020-02          5
# 2020-03          6
# 2020-04         12
# 2020-05          4
# 2020-06          7
# 2020-07         13
# 2020-08         15
# 2020-09         17
# 2020-10         14
# 2020-11          8
# 2020-12          5
# 2021-01          8
# 2021-02          3
# 2021-03          2
# 2021-04          8
# 2021-05          7
# 2021-06          4
# 2021-07          7
# 2021-08          8
# 2021-09          5

# %%
# Convert data frame column to time series (name is used to label the data).
sales_ts = pd.Series(df_new.counts.values, 
                  index=df_new.index, name='counts')
# Define the time series frequency.
sales_ts.index = pd.DatetimeIndex(sales_ts.index,freq='MS')
# Show/print first 5 records of the time series dataset.
print(sales_ts.head())
# Out:
# YM_of_sold
# 2018-10-01    17
# 2018-11-01     7
# 2018-12-01    10
# 2019-01-01     9
# 2019-02-01     9
# Freq: MS, Name: counts, dtype: int64

# %%
# Use seasonal_decompose to develop time series components.
sales_stl = seasonal_decompose(sales_ts, model='additive',period=12)

# Plot time series components.
sales_stl.plot()
plt.show()

# %%
# Define the numbers of months in the training and validation sets,nTrain and nValid, respectively.
nValid = 10
nTrain = len(sales_ts) - nValid
nTrain

# Partition the training data set and show (print) it. 
train_ts = sales_ts[:nTrain]
print('Training Data Set')
print(train_ts)

# Partition the validation data set and show (print) it. 
valid_ts = sales_ts[nTrain:]
print('')
print('Validation Data Set')
print(valid_ts.head())
print(valid_ts.tail())
# Out:
# Training Data Set
# YM_of_sold
# 2018-10-01    17
# 2018-11-01     7
# 2018-12-01    10
# 2019-01-01     9
# 2019-02-01     9
# 2019-03-01    13
# 2019-04-01    13
# 2019-05-01    18
# 2019-06-01    21
# 2019-07-01    16
# 2019-08-01    14
# 2019-09-01    14
# 2019-10-01    11
# 2019-11-01     6
# 2019-12-01     8
# 2020-01-01     6
# 2020-02-01     5
# 2020-03-01     6
# 2020-04-01    12
# 2020-05-01     4
# 2020-06-01     7
# 2020-07-01    13
# 2020-08-01    15
# 2020-09-01    17
# 2020-10-01    14
# 2020-11-01     8
# Freq: MS, Name: counts, dtype: int64
#
# Validation Data Set
# YM_of_sold
# 2020-12-01    5
# 2021-01-01    8
# 2021-02-01    3
# 2021-03-01    2
# 2021-04-01    8
# Freq: MS, Name: counts, dtype: int64
# YM_of_sold
# 2021-05-01    7
# 2021-06-01    4
# 2021-07-01    7
# 2021-08-01    8
# 2021-09-01    5
# Freq: MS, Name: counts, dtype: int64

# %%
# Use auto_arima() function to fit ARIMA model for training data 
#to identify the optimal values of all ARIMA parameters for 
# trend and seasonality. 
train_auto_arima = pm.auto_arima(train_ts, 
                         start_p=1,  d=2, start_q=2, #Model start.
                         test='adf', #Use adftest to find optimal 'd'.
                         max_p=3, max_q=3, #Maximum p and q.  
                         m=12,  #Frequency of time series.
                         seasonal=True, #Allow for seasonality.
                         start_P=0, D=1, start_Q=0,#For seasonlity,D=1.
                         trace=True,  
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True) #Stepwise search for min AIC.

# Use summary() to show auto ARIMA optimal parameters. 
print(train_auto_arima.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,2)(0,1,0)[12]             : AIC=inf, Time=0.31 sec
#  ARIMA(0,2,0)(0,1,0)[12]             : AIC=86.893, Time=0.01 sec
#  ARIMA(1,2,0)(1,1,0)[12]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,2,1)(0,1,1)[12]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,2,0)(1,1,0)[12]             : AIC=88.892, Time=0.12 sec
#  ARIMA(0,2,0)(0,1,1)[12]             : AIC=88.893, Time=0.03 sec
#  ARIMA(0,2,0)(1,1,1)[12]             : AIC=90.892, Time=0.09 sec
#  ARIMA(1,2,0)(0,1,0)[12]             : AIC=86.619, Time=0.02 sec
#  ARIMA(1,2,0)(0,1,1)[12]             : AIC=inf, Time=0.15 sec
#  ARIMA(1,2,0)(1,1,1)[12]             : AIC=90.456, Time=0.20 sec
#  ARIMA(2,2,0)(0,1,0)[12]             : AIC=86.102, Time=0.02 sec
#  ARIMA(2,2,0)(1,1,0)[12]             : AIC=inf, Time=0.16 sec
#  ARIMA(2,2,0)(0,1,1)[12]             : AIC=inf, Time=0.14 sec
#  ARIMA(2,2,0)(1,1,1)[12]             : AIC=89.484, Time=0.28 sec
#  ARIMA(3,2,0)(0,1,0)[12]             : AIC=87.773, Time=0.03 sec
#  ARIMA(2,2,1)(0,1,0)[12]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,2,1)(0,1,0)[12]             : AIC=inf, Time=0.05 sec
#  ARIMA(3,2,1)(0,1,0)[12]             : AIC=inf, Time=0.07 sec
#  ARIMA(2,2,0)(0,1,0)[12] intercept   : AIC=88.065, Time=0.04 sec
#
# Best model:  ARIMA(2,2,0)(0,1,0)[12]
# Total fit time: 1.988 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   26
# Model:             SARIMAX(2, 2, 0)x(0, 1, 0, 12)   Log Likelihood                 -40.051
# Date:                            Mon, 04 Oct 2021   AIC                             86.102
# Time:                                    23:00:54   BIC                             87.557
# Sample:                                         0   HQIC                            85.564
#                                              - 26
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6045      0.327     -1.847      0.065      -1.246       0.037
# ar.L2         -0.4139      0.325     -1.275      0.202      -1.050       0.223
# sigma2        44.2205     25.571      1.729      0.084      -5.898      94.339
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                 0.05
# Prob(Q):                              0.72   Prob(JB):                         0.97
# Heteroskedasticity (H):               1.87   Skew:                            -0.08
# Prob(H) (two-sided):                  0.56   Kurtosis:                         2.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Based on the optimal auto ARIMA parameters, apply SARIMAX()
# function to fit optimal ARIMA model for training data.

train_auto_arima = SARIMAX(train_ts, order=(2, 2, 0), 
              seasonal_order=(0,1,0,12)).fit(disp=0)

# Use summary() to show optimal ARIMA parameters. 
print(train_auto_arima.summary())

# Apply predict() function to make predictions for ts with 
# auto ARIMA model in validation set.  
train_auto_arima_pred = train_auto_arima.predict(start=train_auto_arima.fittedvalues.shape[0], 
                   end=train_auto_arima.fittedvalues.shape[0]+9) 
                         
print(' ')
print('Auto ARIMA Forecast for Validation Period')
print(train_auto_arima_pred)
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             counts   No. Observations:                   26
# Model:             SARIMAX(2, 2, 0)x(0, 1, 0, 12)   Log Likelihood                 -40.051
# Date:                            Mon, 04 Oct 2021   AIC                             86.102
# Time:                                    23:01:00   BIC                             87.557
# Sample:                                10-01-2018   HQIC                            85.564
#                                      - 11-01-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6045      0.327     -1.847      0.065      -1.246       0.037
# ar.L2         -0.4139      0.325     -1.275      0.202      -1.050       0.223
# sigma2        44.2205     25.571      1.729      0.084      -5.898      94.339
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                 0.05
# Prob(Q):                              0.72   Prob(JB):                         0.97
# Heteroskedasticity (H):               1.87   Skew:                            -0.08
# Prob(H) (two-sided):                  0.56   Kurtosis:                         2.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Auto ARIMA Forecast for Validation Period
# 2020-12-01    10.432338
# 2021-01-01     8.412776
# 2021-02-01     7.073498
# 2021-03-01     8.114537
# 2021-04-01    14.058019
# 2021-05-01     5.903050
# 2021-06-01     8.847974
# 2021-07-01    14.773266
# 2021-08-01    16.669076
# 2021-09-01    18.590834
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
# Create a template for graph layout with partitions for data set. 
def Graph_Layout_Partition_Data():
    # Determine coordinates for drawing vertical lines and 
    # horizontal arrows on the chart.    
    one_month = pd.Timedelta('31 days')
    xtrain = (min(train_ts.index), max(train_ts.index) - one_month)
    xvalid = (min(valid_ts.index) + one_month, max(valid_ts.index) - one_month)
    xfuture = (max(valid_ts.index) + one_month, '2022-3')
    xtv = xtrain[1] + 0.5 * (xvalid[0] - xtrain[1])
    xvf = xvalid[1] + 0.5 * (xfuture[0] - xvalid[1])

    ax.axvline(x=xtv, ymin=0, ymax=1, color='black', linewidth=0.5)
    ax.axvline(x=xvf, ymin=0, ymax=1, color='black', linewidth=0.5)

    plt.annotate("", xy=('2020-10', 30), xytext=('2018-10', 30), 
              arrowprops=dict(arrowstyle="<->", shrinkA=0, shrinkB=0))
    plt.annotate("", xy=('2021-9', 30), xytext=('2020-12', 30), 
             arrowprops=dict(arrowstyle="<->", shrinkA=0, shrinkB=0))
    plt.annotate("", xy=('2022-3', 30), xytext=('2021-9', 30), 
             arrowprops=dict(arrowstyle="<->", shrinkA=0, shrinkB=0))

    # Input text on the arrows.
    ax.text('2019-8', 32, 'Training')
    ax.text('2021-3', 32, 'Validation')
    ax.text('2021-12', 32, 'Future')

    # Create limits and axis labels.
    ax.set_xlim('2018-7', '2022-3')
    ax.set_ylim(-5, 40)
    ax.set_xlabel('Time')
    ax.set_ylabel('sold counts')

# %%
# Plot ts data, auto ARIMA model, and predictions for validation period.
train_auto_arima_pred=train_auto_arima_pred.astype(int)
for i in train_auto_arima_pred: 
    if i< 0: 
        print(type(i))
        train_auto_arima_pred=train_auto_arima_pred.replace(i,0)
        
train_auto_arima.fittedvalues=train_auto_arima.fittedvalues.astype(int)
for i in train_auto_arima.fittedvalues: 
    if i< 0: 
        print(type(i))
        train_auto_arima.fittedvalues=train_auto_arima.fittedvalues.replace(i,0)
# Plot entire data set that combines training and validation.
ax = sales_ts.plot(color='black', linewidth=1.5, figsize=(11,7))

# Plot auto ARIMA model for training and valiation sets.
train_auto_arima.fittedvalues.plot(ax = ax, color="blue", linewidth=1.5)
train_auto_arima_pred.plot(ax = ax, color="blue", style='--', linewidth=1.5)

# Use template of graph layout for partitions. 
Graph_Layout_Partition_Data()

# Create graph legend and title.
ax.legend(['sold house Time Series', 'Auto ARIMA Model for Training Period', 
           'Auto ARIMA Forecast for Validation Period'])
plt.title('Auto ARIMA Model')

plt.show()
# Out:
# <class 'int'>
# <class 'int'>

# %%
# Use auto_arima() function to fit ARIMA model for training data
# to identify the optimal values of all ARIMA parameters for 
# trend and seasonality. 
auto_arima_sales = pm.auto_arima(sales_ts, 
                         start_p=1,  d=2, start_q=1, #Model start.
                         test='adf', #Use adftest to find optimal 'd'.
                         max_p=3, max_q=3, #Maximum p and q.  
                         m=12,  #Frequency of time series.
                         seasonal=True, #Allow for seasonality.
                         start_P=0, D=1, start_Q=0,#For seasonlity,D=1.
                         trace=True,  
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True) #Stepwise search for min AIC.

# Use summary() to show auto ARIMA optimal parameters. 
print(auto_arima_sales.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,1,0)[12]             : AIC=inf, Time=0.10 sec
#  ARIMA(0,2,0)(0,1,0)[12]             : AIC=153.866, Time=0.01 sec
#  ARIMA(1,2,0)(1,1,0)[12]             : AIC=150.808, Time=0.03 sec
#  ARIMA(0,2,1)(0,1,1)[12]             : AIC=inf, Time=0.14 sec
#  ARIMA(1,2,0)(0,1,0)[12]             : AIC=150.255, Time=0.01 sec
#  ARIMA(1,2,0)(0,1,1)[12]             : AIC=150.787, Time=0.04 sec
#  ARIMA(1,2,0)(1,1,1)[12]             : AIC=inf, Time=0.26 sec
#  ARIMA(2,2,0)(0,1,0)[12]             : AIC=147.477, Time=0.03 sec
#  ARIMA(2,2,0)(1,1,0)[12]             : AIC=145.067, Time=0.06 sec
#  ARIMA(2,2,0)(2,1,0)[12]             : AIC=inf, Time=0.45 sec
#  ARIMA(2,2,0)(1,1,1)[12]             : AIC=inf, Time=0.25 sec
#  ARIMA(2,2,0)(0,1,1)[12]             : AIC=inf, Time=0.12 sec
#  ARIMA(2,2,0)(2,1,1)[12]             : AIC=147.958, Time=0.57 sec
#  ARIMA(3,2,0)(1,1,0)[12]             : AIC=146.573, Time=0.06 sec
#  ARIMA(2,2,1)(1,1,0)[12]             : AIC=inf, Time=0.15 sec
#  ARIMA(1,2,1)(1,1,0)[12]             : AIC=inf, Time=0.16 sec
#  ARIMA(3,2,1)(1,1,0)[12]             : AIC=inf, Time=0.18 sec
#  ARIMA(2,2,0)(1,1,0)[12] intercept   : AIC=147.051, Time=0.08 sec
#
# Best model:  ARIMA(2,2,0)(1,1,0)[12]
# Total fit time: 2.715 seconds
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                   36
# Model:             SARIMAX(2, 2, 0)x(1, 1, 0, 12)   Log Likelihood                 -68.533
# Date:                            Mon, 04 Oct 2021   AIC                            145.067
# Time:                                    23:01:21   BIC                            149.431
# Sample:                                         0   HQIC                           146.095
#                                              - 36
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8010      0.157     -5.103      0.000      -1.109      -0.493
# ar.L2         -0.6406      0.160     -4.010      0.000      -0.954      -0.327
# ar.S.L12      -0.6761      0.262     -2.585      0.010      -1.189      -0.163
# sigma2        20.2295     13.060      1.549      0.121      -5.368      45.827
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.35   Jarque-Bera (JB):                 0.47
# Prob(Q):                              0.55   Prob(JB):                         0.79
# Heteroskedasticity (H):               0.30   Skew:                            -0.05
# Prob(H) (two-sided):                  0.14   Kurtosis:                         2.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Based on the optimal auto ARIMA parameters, apply SARIMAX()
# function to fit optimal ARIMA model for training data.

auto_arima_sales = SARIMAX(sales_ts, order=(2, 2, 0), 
              seasonal_order=(1,1,0,12)).fit(disp=0)

# Use summary() to show optimal ARIMA parameters. 
print(auto_arima_sales.summary())

# Apply predict() function to make predictions for ts with 
# auto ARIMA model in validation set.  
auto_arima_sales_pred = auto_arima_sales.predict(\
            start=auto_arima_sales.fittedvalues.shape[0], 
            end=auto_arima_sales.fittedvalues.shape[0] + 3) 
                         
print(' ')
print('Auto ARIMA Forecast for Validation Period')
print(auto_arima_sales_pred)
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                             counts   No. Observations:                   36
# Model:             SARIMAX(2, 2, 0)x(1, 1, 0, 12)   Log Likelihood                 -68.533
# Date:                            Mon, 04 Oct 2021   AIC                            145.067
# Time:                                    23:01:24   BIC                            149.431
# Sample:                                10-01-2018   HQIC                           146.095
#                                      - 09-01-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8010      0.157     -5.103      0.000      -1.109      -0.493
# ar.L2         -0.6406      0.160     -4.010      0.000      -0.954      -0.327
# ar.S.L12      -0.6761      0.262     -2.585      0.010      -1.189      -0.163
# sigma2        20.2295     13.060      1.549      0.121      -5.368      45.827
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.35   Jarque-Bera (JB):                 0.47
# Prob(Q):                              0.55   Prob(JB):                         0.79
# Heteroskedasticity (H):               0.30   Skew:                            -0.05
# Prob(H) (two-sided):                  0.14   Kurtosis:                         2.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Auto ARIMA Forecast for Validation Period
# 2021-10-01    4.389953
# 2021-11-01    0.048475
# 2021-12-01   -1.328568
# 2022-01-01   -0.370560
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
#Create a template for graph layout with entire dataset and 12 periods in future. 
def Graph_Layout_Entire_Data():
    # Determine coordinates for drawing vertical lines and horizontal 
    # arrows on the chart.
    one_month = pd.Timedelta('31 days')
    xsold = (min(sales_ts.index), max(sales_ts.index) - one_month)
    xsoldfuture = (max(sales_ts.index) + one_month, '2023')
    xvf = xsold[1] + 0.5 * (xsoldfuture[0] - xsold[1])

    ax.axvline(x=xvf, ymin=0, ymax=1, color='black', linewidth=0.5)

    plt.annotate("", xy=('2021-8', 30), xytext=('2018-10', 30), arrowprops=dict(arrowstyle="<->", shrinkA=0, shrinkB=0))
    plt.annotate("", xy=('2021-9', 30), xytext=('2022-12', 30), arrowprops=dict(arrowstyle="<->", shrinkA=0, shrinkB=0))

    # Input text on the arrows.
    ax.text('2020', 32, 'Training')
    ax.text('2021-12', 32, 'Future')

    # Create limits and axis labels.
    ax.set_xlim('2018-10', '2022-12')
    ax.set_ylim(-5, 40)
    ax.set_xlabel('Time')
    ax.set_ylabel('sold counts')

# %%
# Plot historical data, auto ARIMA model predictions for historical data and forecast for next 3 months
auto_arima_sales_pred=auto_arima_sales_pred.astype(int)
for i in auto_arima_sales_pred: 
    if i< 0: 
        print(type(i))
        auto_arima_sales_pred=auto_arima_sales_pred.replace(i,0)
auto_arima_sales.fittedvalues=auto_arima_sales.fittedvalues.astype(int)
for i in auto_arima_sales.fittedvalues: 
    if i< 0: 
        print(type(i))
        auto_arima_sales.fittedvalues=auto_arima_sales.fittedvalues.replace(i,0)
# Plot entire data set that combines training and validation.
ax = sales_ts.plot(color='black', linewidth=1.5, figsize=(11,7))

# Plot auto ARIMA model for historical data and 12 future periods.
auto_arima_sales.fittedvalues.plot(ax = ax, 
                    color="blue", linewidth=1.5)
auto_arima_sales_pred.plot(ax = ax, 
                    color="blue", style='--', linewidth=1.5)

# Use template of graph layout for partitions. 
Graph_Layout_Entire_Data()

# Create graph legend and title.
ax.legend(['sold house Time Series', 'Auto ARIMA Model for Historical Data', 
           'Auto ARIMA Forecast for 12 Future Periods'])
plt.title('Auto ARIMA Model for Entire Dataset')

plt.show()
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
print('Accuracy Measures for Auto ARIMA Model for Entire Dataset')
regressionSummary(sales_ts, auto_arima_sales.fittedvalues)
# Out:
# Accuracy Measures for Auto ARIMA Model for Entire Dataset
#
# Regression statistics
#
#                       Mean Error (ME) : 0.3056
#        Root Mean Squared Error (RMSE) : 6.9462
#             Mean Absolute Error (MAE) : 5.3056
#           Mean Percentage Error (MPE) : -13.6759
# Mean Absolute Percentage Error (MAPE) : 65.5318

# %% [markdown]
# # Analysis:

# %% [markdown]
# The sales trend is going down after 2021/10 to 2022/01,behind this trend,it maybe beacause holiday season is coming and will affecting on the real estate's market.

# %% [markdown]
# # Reasearch Question 3:

# %% [markdown]
# What is the housing price comparing between Los Angeles,Seattle and San Francisco and which house type is worth for investment?

# %%
filename='single4.csv'
with open(filename) as f:
    reader=csv.reader(f)
    header_row=next(reader)

    dates,LosAngeles,Seattle,SanFrancisco=[],[],[],[]
    for row in reader:
        current_date=datetime.strptime(row[0],"%Y/%m/%d")
        dates.append(current_date)

        price_LA=int(row[1])
        LosAngeles.append(price_LA)

        price_SEA=int(row[4])
        Seattle.append(price_SEA)
        
        price_SF=int(row[3])
        SanFrancisco.append(price_SF)
        
fig=plt.figure(dpi=125,figsize=(10,5))
plt.plot(dates,LosAngeles,c='green',label='Los Angeles')
plt.plot(dates,Seattle,c='blue',label='Seattle')
plt.plot(dates,SanFrancisco,c='red',label='San Francisco')

plt.title("Single Family Sales Comparison",fontsize=16)
plt.xlabel('',fontsize=18)
fig.autofmt_xdate()
plt.ylabel('Median Price(in billion)',fontsize=12)
plt.tick_params(axis='both',which='major',labelsize=12)
plt.legend()

plt.show()

# %%
filename='condo4.csv'
with open(filename) as f:
    reader=csv.reader(f)
    header_row=next(reader)

    dates,LosAngeles,Seattle,SanFrancisco=[],[],[],[]
    for row in reader:
        current_date=datetime.strptime(row[0],"%Y/%m/%d")
        dates.append(current_date)

        price_LA=int(row[1])
        LosAngeles.append(price_LA)

        price_SEA=int(row[4])
        Seattle.append(price_SEA)
        
        price_SF=int(row[3])
        SanFrancisco.append(price_SF) 

fig=plt.figure(dpi=125,figsize=(10,5))
plt.plot(dates,LosAngeles,c='green',label='Los Angeles')
plt.plot(dates,Seattle,c='blue',label='Seattle')
plt.plot(dates,SanFrancisco,c='red',label='San Francisco')

plt.title("Condo Sales Comparison",fontsize=16)
plt.xlabel('',fontsize=18)
fig.autofmt_xdate()
plt.ylabel('Median Price(in billion)',fontsize=12)
plt.tick_params(axis='both',which='major',labelsize=12)
plt.legend()

plt.show()

# %%
filename='townhouse4.csv'
with open(filename) as f:
    reader=csv.reader(f)
    header_row=next(reader)

    dates,LosAngeles,Seattle,SanFrancisco=[],[],[],[]
    for row in reader:
        current_date=datetime.strptime(row[0],"%Y/%m/%d")
        dates.append(current_date)

        price_LA=int(row[1])
        LosAngeles.append(price_LA)

        price_SEA=int(row[4])
        Seattle.append(price_SEA)
        
        price_SF=int(row[3])
        SanFrancisco.append(price_SF)
        
        

fig=plt.figure(dpi=125,figsize=(10,5))
plt.plot(dates,LosAngeles,c='green',label='Los Angeles')
plt.plot(dates,Seattle,c='blue',label='Seattle')
plt.plot(dates,SanFrancisco,c='red',label='San Francisco')

plt.title("Townhouse Sales Comparison",fontsize=16)
plt.xlabel('',fontsize=18)
fig.autofmt_xdate()
plt.ylabel('Median Price(in billion)',fontsize=12)
plt.tick_params(axis='both',which='major',labelsize=12)
plt.legend()

plt.show()

# %% [markdown]
# # Analysis:

# %% [markdown]
# From the investment aspect, the single-family house is the definitely the one worth t
# o put in the money and townhouse might be more risky, and condo is very stable, not a type for investment.

# %% [markdown]
# # Research Question 4:

# %% [markdown]
# Compare appreciation ratio in San Jose, Seattle, Los Angeles and New York.

# %%
# Add region code for current data

sj=pd.read_csv('sanjose.csv')
sj['Region']="San Jose, CA"

la=pd.read_csv('losangeles.csv')
la['Region']="Los Angeles, CA"

se=pd.read_csv('seattle.csv')
se['Region']="Seattle, WA"

ny=pd.read_csv('newyork.csv')
ny['Region']="New York, NY"


# Combine data from SJ,LA,SEATTLE and NY
frames=[sj,la,se,ny]
cities=pd.concat(frames)

cities.drop(cities.columns[0], axis=1,inplace=True)
cities.dtypes
# Out:
# Address        object
# Sold           object
# Sold Date      object
# Bed             int64
# Bath          float64
# Size           object
# Lot Size       object
# HOA            object
# Year Build     object
# Type           object
# Region         object
# dtype: object

# %%
# Data Cleaning - Price

cities['Sold']=cities['Sold'].replace('[\$,]','',regex=True).astype(float)
city=cities.loc[cities['Sold']<4000000]

city['Sold Date']=pd.to_datetime(city['Sold Date'].astype('string')).dt.to_period('M')
data=city.loc[:,['Region','Type','Sold Date','Sold']]

data.to_csv('ar_data_current.csv')
data.head(5)
# Out:
# <ipython-input-17-dbeb9841d56f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['Sold Date']=pd.to_datetime(city['Sold Date'].astype('string')).dt.to_period('M')
#          Region                       Type Sold Date       Sold
# 0  San Jose, CA  Single Family Residential   2021-09  1475000.0
# 1  San Jose, CA                Condo/Co-op   2021-09  1350000.0
# 2  San Jose, CA                Condo/Co-op   2021-09  1260000.0
# 3  San Jose, CA  Single Family Residential   2021-09  1500000.0
# 4  San Jose, CA                Condo/Co-op   2021-09   705000.0

# %%
# Sold Price By Region Summary Cross Tabulation to identify outliers

ct=pd.crosstab(data['Sold'],data['Region'])
ct.tail(10)
# Out:
# Region     Los Angeles, CA  New York, NY  San Jose, CA  Seattle, WA
# Sold
# 3225000.0                1             0             0            0
# 3232000.0                0             0             1            0
# 3240000.0                1             0             0            0
# 3250000.0                0             0             1            0
# 3300000.0                0             1             0            0
# 3350000.0                0             1             0            0
# 3371122.0                0             0             1            0
# 3514157.0                0             0             0            1
# 3752500.0                1             0             0            0
# 3990000.0                0             0             0            2

# %%
# Plot sold price by property type

single=data.loc[data['Type']=='Single Family Residential']
condo=data[data['Type'].isin(['Townhouse','Condo/Co-op'])]


fig, axes = plt.subplots(2,figsize=(13,10),sharex=True)
fig.suptitle('Sold Price Distribution By Region', fontsize=16, fontweight='bold')

sns.boxplot(ax=axes[0],x='Region',y='Sold',hue='Region',data=single,showfliers=False)
sns.boxplot(ax=axes[1],x='Region',y='Sold',hue='Region',data=condo,showfliers=False)

axes[0].set_title('SINGLE FAMILY HOUSE',fontsize=14)
axes[1].set_title('TOWNHOUSE/CONDO',fontsize=14)

axes[0].set_ylabel("Sold Price",fontsize = 14)
axes[1].set_ylabel("Sold Price",fontsize = 14)
axes[1].set_xlabel("Region",fontsize = 14)
plt.xticks()                
                   
plt.savefig('sold_price.png', facecolor='w',dpi=400)

# %%
# Read historical data file
rawsingle=pd.read_csv('single.csv')
rawcondo=pd.read_csv('condo.csv')
rawcondo.dtypes
# Out:
# date                object
# San Jose; CA       float64
# Seattle; WA        float64
# Los Angeles; CA    float64
# New York; NY       float64
# dtype: object

# %%
# data cleaning - date
rawsingle['date']=pd.to_datetime(rawsingle['date'].astype('string')).dt.to_period('M')
rawcondo['date']=pd.to_datetime(rawcondo['date'].astype('string')).dt.to_period('M')

rawcondo.head(3)
# Out:
#       date  San Jose; CA  Seattle; WA  Los Angeles; CA  New York; NY
# 0  2021-07      747460.0     542423.0         673937.0      611850.0
# 1  2021-06      734842.0     537093.0         662035.0      607645.0
# 2  2021-05      718369.0     528647.0         649579.0      604873.0

# %%
# Filter data from 2018- June2021 and rename columns

single_history=rawsingle.loc[(rawsingle['date']>'2017-12-31') & (rawsingle['date']<'2021-7-31')]
single_history.columns=['Date','San Jose, CA','Seattle, WA', 'Los Angeles, CA', 'New York, NY']

condo_history=rawcondo.loc[(rawcondo['date']>'2017-12-31') & (rawcondo['date']<'2021-7-31')]
condo_history.columns=['Date','San Jose, CA','Seattle, WA', 'Los Angeles, CA', 'New York, NY']

condo_history.to_csv('ar_condo_historical.csv')
single_history.to_csv('ar_single_historical.csv')

condo_history.head(3)
# Out:
#       Date  San Jose, CA  Seattle, WA  Los Angeles, CA  New York, NY
# 1  2021-06      734842.0     537093.0         662035.0      607645.0
# 2  2021-05      718369.0     528647.0         649579.0      604873.0
# 3  2021-04      700003.0     513802.0         642941.0      595369.0

# %%
# Convert July-September 2021 Date to be merge with historical data

tempsingle=single.groupby(['Region','Sold Date']).mean().reset_index()
tempsingle['Sold Date']=pd.to_datetime(tempsingle['Sold Date'].astype('string')).dt.to_period('M')

tempcondo=condo.groupby(['Region','Sold Date']).mean().reset_index()
tempcondo['Sold Date']=pd.to_datetime(tempcondo['Sold Date'].astype('string')).dt.to_period('M')

# %%
# Combine historical with Jul-Sep2021 for Single family house

temps_sj=tempsingle[tempsingle['Region']=='San Jose, CA']
temps_se=tempsingle[tempsingle['Region']=='Seattle, WA']
temps_la=tempsingle[tempsingle['Region']=='Los Angeles, CA']
temps_ny=tempsingle[tempsingle['Region']=='New York, NY']

sa=temps_sj.T[1:3].T
sb=temps_se.T[1:3].T
sc=temps_la.T[1:3].T
sd=temps_ny.T[1:3].T

sa.columns=['Date','San Jose, CA']
sb.columns=['Date','Seattle, WA']
sc.columns=['Date','Los Angeles, CA']
sd.columns=['Date','New York, NY']

sa['San Jose, CA']=pd.to_numeric(sa['San Jose, CA'])
sb['Seattle, WA']=pd.to_numeric(sb['Seattle, WA'])
sc['Los Angeles, CA']=pd.to_numeric(sc['Los Angeles, CA'])
sd['New York, NY']=pd.to_numeric(sd['New York, NY'])

sasb=pd.merge(sa,sb)
sasbsc=pd.merge(sasb,sc)
sasbscsd=pd.merge(sasbsc,sd)

full_single=pd.concat([sasbscsd, single_history])
sorted_full_single = full_single.sort_values(by='Date')
sorted_full_single=sorted_full_single.reset_index(drop=True)

# %%
# Combine historical with Jul-Sep2021 for Condo

tempc_sj=tempcondo[tempcondo['Region']=='San Jose, CA']
tempc_se=tempcondo[tempcondo['Region']=='Seattle, WA']
tempc_la=tempcondo[tempcondo['Region']=='Los Angeles, CA']
tempc_ny=tempcondo[tempcondo['Region']=='New York, NY']

ca=tempc_sj.T[1:3].T
ca.columns=['Date','San Jose, CA']
ca['San Jose, CA']=pd.to_numeric(ca['San Jose, CA'])

cb=tempc_se.T[1:3].T
cb.columns=['Date','Seattle, WA']
cb['Seattle, WA']=pd.to_numeric(cb['Seattle, WA'])
cacb=pd.merge(ca,cb)

cc=tempc_la.T[1:3].T
cc.columns=['Date','Los Angeles, CA']
cc['Los Angeles, CA']=pd.to_numeric(cc['Los Angeles, CA'])
cacbcc=pd.merge(cacb,cc)

cd=tempc_ny.T[1:3].T
cd.columns=['Date','New York, NY']
cd['New York, NY']=pd.to_numeric(cd['New York, NY'])
cacbcccd=pd.merge(cacbcc,cd)

full_condo=pd.concat([cacbcccd, condo_history])
sorted_full_condo = full_condo.sort_values(by='Date')
sorted_full_condo=sorted_full_condo.reset_index(drop=True)

# %%
# Plot Price from January 2018-September 2021

fig1,axs = plt.subplots(2,figsize=(15,11),sharex=True)
fig1.suptitle('Price',fontsize=16, fontweight='bold')

sorted_full_single.plot(x='Date',y=['San Jose, CA','Seattle, WA', 'Los Angeles, CA', 'New York, NY'],ax=axs[0],kind='line')
sorted_full_condo.plot(x='Date',y=['San Jose, CA','Seattle, WA', 'Los Angeles, CA', 'New York, NY'],ax=axs[1],kind='line')

axs[0].set_title('Single Family House')
axs[1].set_title('Townhouse/Condo')

axs[0].set_ylabel("Price")
axs[1].set_ylabel("Price")
axs[1].set_xlabel("Month_Year")

plt.xticks()

plt.savefig('history_price.png', facecolor='w', dpi=400)

# %%
# Calculate Appreciation Ratio of 2018-2021 Q3

y2018=sorted_full_single.iloc[6:9].mean()
y2019=sorted_full_single.iloc[18:21].mean()
y2020=sorted_full_single.iloc[30:32].mean()
y2021=sorted_full_single.iloc[42:45].mean()

ardata = (pd.DataFrame({'2018': y2018,'2019':y2019, '2020':y2020,'2021':y2021})).T

ardata.loc['18-19 Change']=(ardata.iloc[1]-ardata.iloc[0])/ardata.iloc[0]
ardata.loc['19-20 Change']=(ardata.iloc[2]-ardata.iloc[1])/ardata.iloc[1]
ardata.loc['20-21 Change']=(ardata.iloc[3]-ardata.iloc[2])/ardata.iloc[2]

ar=ardata.iloc[4:7].T
ar.index.name='Area'

# %%
# Plot appreciation ratio

ar.plot(y=['18-19 Change','19-20 Change','20-21 Change'], kind='bar',figsize=(11,7))

plt.xticks(rotation=45)
plt.title('Single Family House Q3 Appreciation Ratio Comparison',fontsize=14)
plt.savefig('appreciation_ratio.png', facecolor='w', dpi=400)

# %% [markdown]
# # Analysis:

# %% [markdown]
# All four cities have much  higher appreciation ratio compare to national average.
